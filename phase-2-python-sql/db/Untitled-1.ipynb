# %% [markdown]
# # Week 1 — SELECT, WHERE, ORDER BY, LIMIT: Reading & Filtering Data
# ## Phase 2b SQL | PORA Academy Cohort 7 — **Exercises**
#
# Welcome to your first SQL exercises. Each question below comes as **three cells**:
#
# 1. A **question** with the task and an **Expected** result.
# 2. A blank `%%sql` answer cell — write your query where it says `-- Your query here`, capturing the result into a variable (e.g. `q1`).
# 3. A **check cell** (plain Python) — run it after your query. A ✅ means you got it right.
#
# **Do not edit the check cells.** Run the setup cell first, then work top to bottom.

# %% [markdown]
# ### Setup — run this cell first
# Loads the Olist tables into a file-based SQLite database and connects `%%sql`. Because `autopandas` is on, every `%%sql` result is a pandas DataFrame your check cells can inspect.

# %%
from pathlib import Path

root = Path().resolve()
print("cwd:", root)

matches = list(root.rglob("olist_orders_dataset.csv"))
print("matches:", matches)
# Out:
# cwd: C:\Users\USER\Desktop\Pora Academy\data-analysis-and-ai-automation-course-cohort-7\.claude\skills\sql-notebook-generate\examples
# matches: []

# %%
# %pip install ipython-sql sqlalchemy
# Out:
# Requirement already satisfied: ipython-sql in c:\users\user\anaconda3\lib\site-packages (0.5.0)
# Requirement already satisfied: sqlalchemy in c:\users\user\anaconda3\lib\site-packages (2.0.43)
# Requirement already satisfied: prettytable in c:\users\user\anaconda3\lib\site-packages (from ipython-sql) (3.18.0)
# Requirement already satisfied: ipython in c:\users\user\anaconda3\lib\site-packages (from ipython-sql) (9.7.0)
# Requirement already satisfied: sqlparse in c:\users\user\anaconda3\lib\site-packages (from ipython-sql) (0.5.5)
# Requirement already satisfied: six in c:\users\user\anaconda3\lib\site-packages (from ipython-sql) (1.17.0)
# Requirement already satisfied: ipython-genutils in c:\users\user\anaconda3\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: greenlet>=1 in c:\users\user\anaconda3\lib\site-packages (from sqlalchemy) (3.2.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\user\anaconda3\lib\site-packages (from sqlalchemy) (4.15.0)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\user\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\user\anaconda3\lib\site-packages (from ipython->ipython-sql) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\user\anaconda3\lib\site-packages (from ipython->ipython-sql) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\user\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in c:\users\user\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\user\anaconda3\lib\site-packages (from ipython->ipython-sql) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\user\anaconda3\lib\site-packages (from ipython->ipython-sql) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\user\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\user\anaconda3\lib\site-packages (from ipython->ipython-sql) (5.14.3)
# Requirement already satisfied: wcwidth in c:\users\user\anaconda3\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->ipython-sql) (0.8.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\user\anaconda3\lib\site-packages (from jedi>=0.18.1->ipython->ipython-sql) (0.8.5)
# Requirement already satisfied: executing>=1.2.0 in c:\users\user\anaconda3\lib\site-packages (from stack_data>=0.6.0->ipython->ipython-sql) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\user\anaconda3\lib\site-packages (from stack_data>=0.6.0->ipython->ipython-sql) (3.0.0)
# Requirement already satisfied: pure_eval in c:\users\user\anaconda3\lib\site-packages (from stack_data>=0.6.0->ipython->ipython-sql) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install jupysql
# Out:
# Requirement already satisfied: jupysql in c:\users\user\anaconda3\lib\site-packages (0.11.1)
# Requirement already satisfied: prettytable>=3.12.0 in c:\users\user\anaconda3\lib\site-packages (from jupysql) (3.18.0)
# Requirement already satisfied: sqlalchemy in c:\users\user\anaconda3\lib\site-packages (from jupysql) (2.0.43)
# Requirement already satisfied: sqlparse in c:\users\user\anaconda3\lib\site-packages (from jupysql) (0.5.5)
# Requirement already satisfied: ipython-genutils>=0.1.0 in c:\users\user\anaconda3\lib\site-packages (from jupysql) (0.2.0)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\lib\site-packages (from jupysql) (3.1.6)
# Requirement already satisfied: sqlglot>=11.3.7 in c:\users\user\anaconda3\lib\site-packages (from jupysql) (30.15.0)
# Requirement already satisfied: jupysql-plugin>=0.4.2 in c:\users\user\anaconda3\lib\site-packages (from jupysql) (0.4.5)
# Requirement already satisfied: ploomber-core>=0.2.7 in c:\users\user\anaconda3\lib\site-packages (from jupysql) (0.2.27)
# Requirement already satisfied: pyyaml in c:\users\user\anaconda3\lib\site-packages (from ploomber-core>=0.2.7->jupysql) (6.0.3)
# Requirement already satisfied: posthog>=3.0 in c:\users\user\anaconda3\lib\site-packages (from ploomber-core>=0.2.7->jupysql) (7.37.6)
# Requirement already satisfied: requests<3.0,>=2.7 in c:\users\user\anaconda3\lib\site-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2.32.5)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\user\anaconda3\lib\site-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\user\anaconda3\lib\site-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (1.9.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\user\anaconda3\lib\site-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2026.6.17)
# Requirement already satisfied: wcwidth>=0.3.5 in c:\users\user\anaconda3\lib\site-packages (from prettytable>=3.12.0->jupysql) (0.8.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\lib\site-packages (from jinja2->jupysql) (3.0.2)
# Requirement already satisfied: greenlet>=1 in c:\users\user\anaconda3\lib\site-packages (from sqlalchemy->jupysql) (3.2.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
"""
Standard Olist SQL Setup for Google Colab — Phase 2b SQL

Use this block as the FIRST code cell in every Phase 2b notebook (all weeks).

Design notes (why this differs from the Phase 2a pandas setup):
- We teach SQL with the `%%sql` cell magic (jupysql) so beginners write raw
  SQL, not `pd.read_sql("...")` strings. Students meet SQL syntax first;
  the Python wrapper comes later (Phase 2c).
- jupysql opens its OWN database connection. A `sqlite3.connect(":memory:")`
  database is private to that one connection, so a separate `%sql sqlite://`
  connection would see ZERO tables. We therefore build a **file-based**
  SQLite database at /content/olist.db and point both pandas (for loading)
  and jupysql (for querying) at the same file.
- `autopandas = True` makes every `%%sql` cell return a pandas DataFrame, so
  self-check cells can `assert` on `.iloc`/`.shape` directly.

After this cell runs, query with:

    # %%sql
    SELECT * FROM orders LIMIT 5

Or capture a result for checking:

    # %%sql result <<
    SELECT COUNT(*) AS n FROM orders WHERE order_status = 'delivered'
    # then in a plain Python cell:  assert int(result.iloc[0]['n']) == 96478
"""

from pathlib import Path
import os
import sqlite3
import pandas as pd
# from google.colab import drive

# 1) Mount Drive and locate the Olist CSVs
# drive.mount('/content/drive')
DATA_DIR = Path(r"c:\Users\USER\Desktop\Pora Academy\data-analysis-and-ai-automation-course-cohort-7\phase-2-python-sql")

# 2) Create a local directory for the SQLite database file
DB_DIR = os.path.join(os.getcwd(), "db")
os.makedirs(DB_DIR, exist_ok=True)

# 3) Build a file-based SQLite database (shared by pandas + jupysql)
DB_PATH = os.path.join(DB_DIR, "olist.db")
conn = sqlite3.connect(DB_PATH)

tables = {
    "orders": "olist_orders_dataset.csv",
    "customers": "olist_customers_dataset.csv",
    "order_items": "olist_order_items_dataset.csv",
    "order_payments": "olist_order_payments_dataset.csv",
    "order_reviews": "olist_order_reviews_dataset.csv",
    "products": "olist_products_dataset.csv",
    "sellers": "olist_sellers_dataset.csv",
    "product_category_translation": "product_category_name_translation.csv",
}

for table_name, filename in tables.items():
    path = DATA_DIR / filename
    if not path.exists():
        raise FileNotFoundError(path)
    df = pd.read_csv(path)
    df.to_sql(table_name, conn, if_exists="replace", index=False)

conn.close()
print("\nDatabase ready.")

# 3) Connect jupysql to the SAME database file
# %load_ext sql
# %config SqlMagic.autopandas = True          # %%sql cells return DataFrames
# %config SqlMagic.feedback = 0               # quieter output
# %sql sqlite:////{DB_PATH}

# Verify (expected row counts — do not alter without re-running against data):
#   orders 99,441 | customers 99,441 | order_items 112,650 | order_payments 103,886
#   order_reviews 99,224 | products 32,951 | sellers 3,095 | product_category_translation 71
# Out:
# Database ready.
# RuntimeError: (sqlite3.OperationalError) unable to open database file
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# ## Question 1 — Count delivered orders
#
# The `orders` table has an `order_status` column. Count how many orders have a status of `delivered`. Alias the count as `n`.
#
# **Expected:** 96,478 delivered orders

# %%
# %%sql q1 <<
# -- Your query here
# Out:
# Traceback (most recent call last):
#   File "c:\Users\USER\anaconda3\Lib\site-packages\sql\magic.py", line 196, in execute
#     @validate("dsn_filename")
#                    ^^^^^^^^^^
#     ...<4 lines>...
#     # To verify displaylimit is valid positive integer
#     ^^^^^^^^^
#   File "c:\Users\USER\anaconda3\Lib\site-packages\sql\connection.py", line 82, in set
#     raise ConnectionError(
#         "Environment variable $DATABASE_URL not set, and no connect string given."
#     )
# sql.connection.ConnectionError: Environment variable $DATABASE_URL not set, and no connect string given.
#
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
# --- CHECK Q1 — do not edit ---
assert int(q1.iloc[0]['n']) == 96478, "Q1: expected 96,478 delivered orders"
print("✅ Q1 correct")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 # --- CHECK Q1 — do not edit ---
# ----> 2 assert int(q1.iloc[0]['n']) == 96478, "Q1: expected 96,478 delivered orders"
#       3 print("✅ Q1 correct")
#
# NameError: name 'q1' is not defined

# %% [markdown]
# ## Question 2 — Count canceled orders
#
# Count how many orders have an `order_status` of `canceled`. Alias the count as `n`.
#
# **Expected:** 625 canceled orders

# %%
# %%sql q2 <<
# -- Your query here

# %%
# --- CHECK Q2 — do not edit ---
assert int(q2.iloc[0]['n']) == 625, "Q2: expected 625 canceled orders"
print("✅ Q2 correct")

# %% [markdown]
# ## Question 3 — Orders that are NOT delivered
#
# Use `!=` to count every order whose `order_status` is **not** `delivered`. Alias the count as `n`.
#
# **Expected:** 2,963 non-delivered orders

# %%
# %%sql q3 <<
# -- Your query here

# %%
# --- CHECK Q3 — do not edit ---
assert int(q3.iloc[0]['n']) == 2963, "Q3: expected 2,963 non-delivered orders"
print("✅ Q3 correct")

# %% [markdown]
# ## Question 4 — Canceled OR unavailable
#
# Use `OR` in the `WHERE` clause to count orders whose `order_status` is either `canceled` **or** `unavailable`. Alias the count as `n`.
#
# **Expected:** 1,234 orders (625 canceled + 609 unavailable)

# %%
# %%sql q4 <<
# -- Your query here

# %%
# --- CHECK Q4 — do not edit ---
assert int(q4.iloc[0]['n']) == 1234, "Q4: expected 1,234 canceled-or-unavailable orders"
print("✅ Q4 correct")

# %% [markdown]
# ## Question 5 — Total number of orders
#
# How many orders are in the `orders` table in total? Use `COUNT(*)`.
#
# **Expected:** 99,441

# %%
# %%sql q5 <<
# -- Your query here

# %%
# --- CHECK Q5 — do not edit ---
assert int(q5.iloc[0]['n']) == 99441, "Q5: expected 99,441 total orders"
print("✅ Q5 correct")
